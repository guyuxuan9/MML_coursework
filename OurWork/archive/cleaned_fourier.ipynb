# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import StandardScaler

# Load and round off data for dimension 45
X = np.load('Datasets/kryptonite-45-X.npy')
y = np.load('Datasets/kryptonite-45-y.npy')
# X = np.round(X)  # Round to nearest integer (0 or 1)

# Create DataFrame for easier handling
df = pd.DataFrame(X, columns=[f'Feature_{i+1}' for i in range(X.shape[1])])
df['Target'] = y

# Standardize features for better correlation visualization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df.drop(columns=['Target']))
df_scaled = pd.DataFrame(X_scaled, columns=df.columns[:-1])
df_scaled['Target'] = df['Target']

# Pairwise scatter plot for features
sns.pairplot(df_scaled, plot_kws={'alpha': 0.3, 's': 10})
plt.suptitle('Pairwise Scatter Plot of Features (Dim 45)', y=1.02)
plt.show()

# Compute mutual information between each feature and the target
mi_scores = mutual_info_classif(X, y, discrete_features=True)
mi_df = pd.DataFrame({'Feature': df.columns[:-1], 'Mutual Information': mi_scores})
mi_df = mi_df.sort_values(by='Mutual Information', ascending=False)

# Plot mutual information scores
plt.figure(figsize=(10, 6))
sns.barplot(x='Mutual Information', y='Feature', data=mi_df, palette='viridis')
plt.title('Mutual Information between Each Feature and Target')
plt.xlabel('Mutual Information Score')
plt.ylabel('Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 24
#      21 df_scaled['Target'] = df['Target']
#      23 # Pairwise scatter plot for features
# ---> 24 sns.pairplot(df_scaled, plot_kws={'alpha': 0.3, 's': 10})
#      25 plt.suptitle('Pairwise Scatter Plot of Features (Dim 45)', y=1.02)
#      26 plt.show()
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/seaborn/axisgrid.py:2163, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2161 if kind == "scatter":
#    2162     from .relational import scatterplot  # Avoid circular import
# -> 2163     plotter(scatterplot, **plot_kws)
#    2164 elif kind == "reg":
#    2165     from .regression import regplot  # Avoid circular import
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/seaborn/axisgrid.py:1425, in PairGrid.map_offdiag(self, func, **kwargs)
#    1414 """Plot with a bivariate function on the off-diagonal subplots.
#    1415
#    1416 Parameters
#    (...)
#    1422
#    1423 """
#    1424 if self.square_grid:
# -> 1425     self.map_lower(func, **kwargs)
#    1426     if not self._corner:
#    1427         self.map_upper(func, **kwargs)
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/seaborn/axisgrid.py:1395, in PairGrid.map_lower(self, func, **kwargs)
#    1384 """Plot with a bivariate function on the lower diagonal subplots.
#    1385
#    1386 Parameters
#    (...)
#    1392
#    1393 """
#    1394 indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1395 self._map_bivariate(func, indices, **kwargs)
#    1396 return self
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/seaborn/axisgrid.py:1574, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1572     if ax is None:  # i.e. we are in corner mode
#    1573         continue
# -> 1574     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1575 self._add_axis_labels()
#    1577 if "hue" in signature(func).parameters:
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/seaborn/axisgrid.py:1615, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1611 if "hue" not in kwargs:
#    1612     kwargs.update({
#    1613         "hue": hue, "hue_order": self._hue_order, "palette": self._orig_palette,
#    1614     })
# -> 1615 func(x=x, y=y, **kwargs)
#    1617 self._update_legend_data(ax)
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/seaborn/relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/seaborn/relational.py:461, in _ScatterPlotter.plot(self, ax, kws)
#     458     kws["linewidth"] = linewidth
#     460 # Finalize the axes details
# --> 461 self._add_axis_labels(ax)
#     462 if self.legend:
#     463     attrs = {"hue": "color", "size": "s", "style": None}
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/seaborn/_base.py:1196, in VectorPlotter._add_axis_labels(self, ax, default_x, default_y)
#    1191 # TODO ax could default to None and use attached axes if present
#    1192 # but what to do about the case of facets? Currently using FacetGrid's
#    1193 # set_axis_labels method, which doesn't add labels to the interior even
#    1194 # when the axes are not shared. Maybe that makes sense?
#    1195 if not ax.get_xlabel():
# -> 1196     x_visible = any(t.get_visible() for t in ax.get_xticklabels())
#    1197     ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1198 if not ax.get_ylabel():
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axis.py:1503, in Axis.get_ticklabels(self, minor, which)
#    1501 if minor:
#    1502     return self.get_minorticklabels()
# -> 1503 return self.get_majorticklabels()
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axis.py:1460, in Axis.get_majorticklabels(self)
#    1458 def get_majorticklabels(self):
#    1459     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1460     self._update_ticks()
#    1461     ticks = self.get_major_ticks()
#    1462     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axis.py:1300, in Axis._update_ticks(self)
#    1295 def _update_ticks(self):
#    1296     """
#    1297     Update ticks (position and labels) using the current data interval of
#    1298     the axes.  Return the list of ticks that will be drawn.
#    1299     """
# -> 1300     major_locs = self.get_majorticklocs()
#    1301     major_labels = self.major.formatter.format_ticks(major_locs)
#    1302     major_ticks = self.get_major_ticks(len(major_locs))
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axis.py:1531, in Axis.get_majorticklocs(self)
#    1529 def get_majorticklocs(self):
#    1530     """Return this Axis' major tick locations in data coordinates."""
# -> 1531     return self.major.locator()
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/ticker.py:2170, in MaxNLocator.__call__(self)
#    2169 def __call__(self):
# -> 2170     vmin, vmax = self.axis.get_view_interval()
#    2171     return self.tick_values(vmin, vmax)
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axis.py:2312, in _make_getset_interval.<locals>.getter(self)
#    2310 def getter(self):
#    2311     # docstring inherited.
# -> 2312     return getattr(getattr(self.axes, lim_name), attr_name)
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axes/_base.py:852, in _AxesBase.viewLim(self)
#     850 @property
#     851 def viewLim(self):
# --> 852     self._unstale_viewLim()
#     853     return self._viewLim
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axes/_base.py:847, in _AxesBase._unstale_viewLim(self)
#     845     for ax in self._shared_axes[name].get_siblings(self):
#     846         ax._stale_viewlims[name] = False
# --> 847 self.autoscale_view(**{f"scale{name}": scale
#     848                        for name, scale in need_scale.items()})
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axes/_base.py:2998, in _AxesBase.autoscale_view(self, tight, scalex, scaley)
#    2995     set_bound(x0, x1)
#    2996     # End of definition of internal function 'handle_single_axis'.
# -> 2998 handle_single_axis(
#    2999     scalex, self._shared_axes["x"], 'x', self.xaxis, self._xmargin,
#    3000     x_stickies, self.set_xbound)
#    3001 handle_single_axis(
#    3002     scaley, self._shared_axes["y"], 'y', self.yaxis, self._ymargin,
#    3003     y_stickies, self.set_ybound)
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axes/_base.py:2995, in _AxesBase.autoscale_view.<locals>.handle_single_axis(scale, shared_axes, name, axis, margin, stickies, set_bound)
#    2993 if not self._tight:
#    2994     x0, x1 = locator.view_limits(x0, x1)
# -> 2995 set_bound(x0, x1)
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axes/_base.py:3618, in _AxesBase.set_xbound(self, lower, upper)
#    3615 if upper is None:
#    3616     upper = old_upper
# -> 3618 self.set_xlim(sorted((lower, upper),
#    3619                      reverse=bool(self.xaxis_inverted())),
#    3620               auto=None)
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axes/_base.py:3739, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3737         raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3738     right = xmax
# -> 3739 return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/axis.py:1283, in Axis._set_lim(self, v0, v1, emit, auto)
#    1281 other._axis_map[name]._set_lim(v0, v1, emit=False, auto=auto)
#    1282 if emit:
# -> 1283     other.callbacks.process(f"{name}lim_changed", other)
#    1284 if other.figure != self.figure:
#    1285     other.figure.canvas.draw_idle()
#
# File ~/opt/anaconda3/envs/ml2/lib/python3.10/site-packages/matplotlib/cbook.py:285, in CallbackRegistry.process(self, s, *args, **kwargs)
#     282         del self.callbacks[signal]
#     283         del self._func_cid_map[signal]
# --> 285 def process(self, s, *args, **kwargs):
#     286     """
#     287     Process signal *s*.
#     288
#     289     All of the functions registered to receive callbacks on *s* will be
#     290     called with ``*args`` and ``**kwargs``.
#     291     """
#     292     if self._signals is not None:
#
# KeyboardInterrupt:
